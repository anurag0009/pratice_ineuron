# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np

# %%
dir(pd)
# Out:
# ['BooleanDtype',
#  'Categorical',
#  'CategoricalDtype',
#  'CategoricalIndex',
#  'DataFrame',
#  'DateOffset',
#  'DatetimeIndex',
#  'DatetimeTZDtype',
#  'ExcelFile',
#  'ExcelWriter',
#  'Flags',
#  'Float32Dtype',
#  'Float64Dtype',
#  'Float64Index',
#  'Grouper',
#  'HDFStore',
#  'Index',
#  'IndexSlice',
#  'Int16Dtype',
#  'Int32Dtype',
#  'Int64Dtype',
#  'Int64Index',
#  'Int8Dtype',
#  'Interval',
#  'IntervalDtype',
#  'IntervalIndex',
#  'MultiIndex',
#  'NA',
#  'NaT',
#  'NamedAgg',
#  'Period',
#  'PeriodDtype',
#  'PeriodIndex',
#  'RangeIndex',
#  'Series',
#  'SparseDtype',
#  'StringDtype',
#  'Timedelta',
#  'TimedeltaIndex',
#  'Timestamp',
#  'UInt16Dtype',
#  'UInt32Dtype',
#  'UInt64Dtype',
#  'UInt64Index',
#  'UInt8Dtype',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__deprecated_num_index_names',
#  '__dir__',
#  '__doc__',
#  '__docformat__',
#  '__file__',
#  '__getattr__',
#  '__git_version__',
#  '__loader__',
#  '__name__',
# ...

# %%
help(pd.DataFrame)
# Out:
# Help on class DataFrame in module pandas.core.frame:
#
# class DataFrame(pandas.core.generic.NDFrame, pandas.core.arraylike.OpsMixin)
#  |  DataFrame(data=None, index: 'Axes | None' = None, columns: 'Axes | None' = None, dtype: 'Dtype | None' = None, copy: 'bool | None' = None)
#  |
#  |  Two-dimensional, size-mutable, potentially heterogeneous tabular data.
#  |
#  |  Data structure also contains labeled axes (rows and columns).
#  |  Arithmetic operations align on both row and column labels. Can be
#  |  thought of as a dict-like container for Series objects. The primary
#  |  pandas data structure.
#  |
#  |  Parameters
#  |  ----------
#  |  data : ndarray (structured or homogeneous), Iterable, dict, or DataFrame
#  |      Dict can contain Series, arrays, constants, dataclass or list-like objects. If
#  |      data is a dict, column order follows insertion-order. If a dict contains Series
#  |      which have an index defined, it is aligned by its index.
#  |
# ...

# %%
#Importing your dataset

# %%
cd data_cleaning_bepec_july
# Out:
# /Users/anuragsingh/Desktop/Data Science/data_cleaning_bepec_july

# %%
hd = pd.read_csv('clevelanda.csv')

# %%
hd
# Out:
#      age  gender  cp  trestbps  chol  fps  restecg  thalach  exang  oldpeak  \
# 0     63       1   1       145   233    1        2      150      0      2.3
# 1     67       1   4       160   286    0        2      108      1      1.5
# 2     67       1   4       120   229    0        2      129      1      2.6
# 3     37       1   3       130   250    0        0      187      0      3.5
# 4     41       0   2       130   204    0        2      172      0      1.4
# ..   ...     ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   45       1   1       110   264    0        0      132      0      1.2
# 299   68       1   4       144   193    1        0      141      0      3.4
# 300   57       1   4       130   131    0        0      115      1      1.2
# 301   57       0   2       130   236    0        2      174      0      0.0
# 302   38       1   3       138   175    0        0      173      0      0.0
#
#      slope ca thal  class
# 0        3  0    6      0
# ...

# %%
#Data Understanding

# %%
#Data Accessing
hd['class']
# Out:
# 0      0
# 1      2
# 2      1
# 3      0
# 4      0
#       ..
# 298    1
# 299    2
# 300    3
# 301    1
# 302    0
# Name: class, Length: 303, dtype: int64

# %%
hd.iloc[:5,:5]
# Out:
#    age  gender  cp  trestbps  chol
# 0   63       1   1       145   233
# 1   67       1   4       160   286
# 2   67       1   4       120   229
# 3   37       1   3       130   250
# 4   41       0   2       130   204

# %%
hd.iloc[5:10, 1:8]
# Out:
#    gender  cp  trestbps  chol  fps  restecg  thalach
# 5       1   2       120   236    0        0      178
# 6       0   4       140   268    0        2      160
# 7       0   4       120   354    0        0      163
# 8       1   4       130   254    0        2      147
# 9       1   4       140   203    1        2      155

# %%
hd['class'].unique()
# Out:
# array([0, 2, 1, 3, 4])

# %%
hd['class'].value_counts()
# Out:
# 0    164
# 1     55
# 2     36
# 3     35
# 4     13
# Name: class, dtype: int64

# %%
import seaborn as sns

# %%
sns.countplot(hd['class'])
# Out:
# /Users/anuragsingh/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='class', ylabel='count'>

# %%
hd['age'].mean()
# Out:
# 54.43894389438944

# %%
hd['age'].min()
# Out:
# 29

# %%
hd['age'].max()
# Out:
# 77

# %%
hd['age'].describe()
# Out:
# count    303.000000
# mean      54.438944
# std        9.038662
# min       29.000000
# 25%       48.000000
# 50%       56.000000
# 75%       61.000000
# max       77.000000
# Name: age, dtype: float64

# %%
hd.pivot_table(values = ['age'], index = ['class','gender'], aggfunc ='mean')
# Out:
#                     age
# class gender
# 0     0       54.555556
#       1       51.043478
# 1     0       60.333333
#       1       54.413043
# 2     0       55.285714
#       1       58.689655
# 3     0       59.857143
#       1       55.035714
# 4     0       64.000000
#       1       58.909091

# %%
hd.groupby(['age']).mean()
# Out:
#        gender        cp    trestbps        chol       fps   restecg  \
# age
# 29   1.000000  2.000000  130.000000  204.000000  0.000000  2.000000
# 34   0.500000  1.500000  118.000000  196.000000  0.000000  1.000000
# 35   0.750000  3.500000  126.500000  213.750000  0.000000  0.500000
# 37   0.500000  3.000000  125.000000  232.500000  0.000000  0.000000
# 38   1.000000  2.000000  129.000000  203.000000  0.000000  0.000000
# 39   0.500000  3.250000  122.500000  239.750000  0.000000  0.500000
# 40   1.000000  3.000000  134.000000  196.333333  0.000000  0.666667
# 41   0.600000  2.500000  119.000000  220.700000  0.000000  0.800000
# 42   0.750000  3.000000  127.000000  246.750000  0.125000  0.500000
# 43   0.750000  3.750000  126.375000  256.750000  0.250000  0.750000
# 44   0.818182  3.000000  120.727273  221.363636  0.000000  0.727273
# 45   0.625000  2.875000  122.375000  247.375000  0.000000  1.500000
# 46   0.571429  3.142857  128.000000  230.285714  0.142857  0.857143
# ...

# %%
hd.columns
# Out:
# Index(['age', 'gender', 'cp', 'trestbps', 'chol', 'fps', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'class'],
#       dtype='object')

# %%
hd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   gender    303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fps       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    object
#  12  thal      303 non-null    object
#  13  class     303 non-null    int64
# dtypes: float64(1), int64(11), object(2)
# memory usage: 33.3+ KB

# %%
hd.head()
# Out:
#    age  gender  cp  trestbps  chol  fps  restecg  thalach  exang  oldpeak  \
# 0   63       1   1       145   233    1        2      150      0      2.3
# 1   67       1   4       160   286    0        2      108      1      1.5
# 2   67       1   4       120   229    0        2      129      1      2.6
# 3   37       1   3       130   250    0        0      187      0      3.5
# 4   41       0   2       130   204    0        2      172      0      1.4
#
#    slope ca thal  class
# 0      3  0    6      0
# 1      2  3    3      2
# 2      2  2    7      1
# 3      3  0    3      0
# 4      1  0    3      0

# %%
hd.head(10)
# Out:
#    age  gender  cp  trestbps  chol  fps  restecg  thalach  exang  oldpeak  \
# 0   63       1   1       145   233    1        2      150      0      2.3
# 1   67       1   4       160   286    0        2      108      1      1.5
# 2   67       1   4       120   229    0        2      129      1      2.6
# 3   37       1   3       130   250    0        0      187      0      3.5
# 4   41       0   2       130   204    0        2      172      0      1.4
# 5   56       1   2       120   236    0        0      178      0      0.8
# 6   62       0   4       140   268    0        2      160      0      3.6
# 7   57       0   4       120   354    0        0      163      1      0.6
# 8   63       1   4       130   254    0        2      147      0      1.4
# 9   53       1   4       140   203    1        2      155      1      3.1
#
#    slope ca thal  class
# 0      3  0    6      0
# 1      2  3    3      2
# 2      2  2    7      1
# 3      3  0    3      0
# 4      1  0    3      0
# ...

# %%
hd['ca'].value_counts()
# Out:
# 0       176
# 1        65
# 2        38
# 3        20
# July      4
# Name: ca, dtype: int64

# %%
hd['thal'].value_counts()
# Out:
# 3    166
# 7    117
# 6     18
# ?      2
# Name: thal, dtype: int64

# %%
hd['ca'] = hd['ca'].replace('?', 'July')

# %%
hd['ca'].value_counts()
# Out:
# 0       176
# 1        65
# 2        38
# 3        20
# July      4
# Name: ca, dtype: int64

# %%
hd['ca'] = hd['ca'].replace('July', np.nan)

# %%
hd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   gender    303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fps       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        299 non-null    object
#  12  thal      301 non-null    object
#  13  class     303 non-null    int64
# dtypes: float64(1), int64(11), object(2)
# memory usage: 33.3+ KB

# %%
hd.isnull().sum()
# Out:
# age         0
# gender      0
# cp          0
# trestbps    0
# chol        0
# fps         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          4
# thal        2
# class       0
# dtype: int64

# %%
hd['thal'] = hd['thal'].replace('?', np.nan)

# %%
hd.isnull().sum()
# Out:
# age         0
# gender      0
# cp          0
# trestbps    0
# chol        0
# fps         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          4
# thal        2
# class       0
# dtype: int64

# %%
hd = hd.dropna()

# %%
hd.isnull().sum()
# Out:
# age         0
# gender      0
# cp          0
# trestbps    0
# chol        0
# fps         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# class       0
# dtype: int64

# %%
hd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 297 entries, 0 to 301
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       297 non-null    int64
#  1   gender    297 non-null    int64
#  2   cp        297 non-null    int64
#  3   trestbps  297 non-null    int64
#  4   chol      297 non-null    int64
#  5   fps       297 non-null    int64
#  6   restecg   297 non-null    int64
#  7   thalach   297 non-null    int64
#  8   exang     297 non-null    int64
#  9   oldpeak   297 non-null    float64
#  10  slope     297 non-null    int64
#  11  ca        297 non-null    object
#  12  thal      297 non-null    object
#  13  class     297 non-null    int64
# dtypes: float64(1), int64(11), object(2)
# memory usage: 34.8+ KB

# %%
hd
# Out:
#      age  gender  cp  trestbps  chol  fps  restecg  thalach  exang  oldpeak  \
# 0     63       1   1       145   233    1        2      150      0      2.3
# 1     67       1   4       160   286    0        2      108      1      1.5
# 2     67       1   4       120   229    0        2      129      1      2.6
# 3     37       1   3       130   250    0        0      187      0      3.5
# 4     41       0   2       130   204    0        2      172      0      1.4
# ..   ...     ...  ..       ...   ...  ...      ...      ...    ...      ...
# 297   57       0   4       140   241    0        0      123      1      0.2
# 298   45       1   1       110   264    0        0      132      0      1.2
# 299   68       1   4       144   193    1        0      141      0      3.4
# 300   57       1   4       130   131    0        0      115      1      1.2
# 301   57       0   2       130   236    0        2      174      0      0.0
#
#      slope ca thal  class
# 0        3  0    6      0
# ...

# %%
de = {'training':['DA','ML','DL','AI',np.nan], 'hours':[np.nan,np.nan,5,6,np.nan], 'tools':[np.nan,np.nan,np.nan,4,np.nan]}

# %%
df = pd.DataFrame(de)

# %%
df
# Out:
#   training  hours  tools
# 0       DA    NaN    NaN
# 1       ML    NaN    NaN
# 2       DL    5.0    NaN
# 3       AI    6.0    4.0
# 4      NaN    NaN    NaN

# %%
df.dropna(axis = 0)
# Out:
#   training  hours  tools
# 3       AI    6.0    4.0

# %%
df.dropna(axis = 1)
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4]

# %%
hd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 297 entries, 0 to 301
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       297 non-null    int64
#  1   gender    297 non-null    int64
#  2   cp        297 non-null    int64
#  3   trestbps  297 non-null    int64
#  4   chol      297 non-null    int64
#  5   fps       297 non-null    int64
#  6   restecg   297 non-null    int64
#  7   thalach   297 non-null    int64
#  8   exang     297 non-null    int64
#  9   oldpeak   297 non-null    float64
#  10  slope     297 non-null    int64
#  11  ca        297 non-null    int64
#  12  thal      297 non-null    int64
#  13  class     297 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 34.8 KB

# %%
hd['thal'] = pd.to_numeric(hd['thal'])
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
hd['age'].hist()

# %%
sns.boxplot(hd['age'])

# %%
hd['age'].describe()
# Out:
# count    297.000000
# mean      54.542088
# std        9.049736
# min       29.000000
# 25%       48.000000
# 50%       56.000000
# 75%       61.000000
# max       77.000000
# Name: age, dtype: float64

# %%
sns.lineplot(x = hd['age'], y = hd['thalach'])

# %%
sns.boxplot(hd['thalach'])

# %%
#Minimum Outlier = Q1 - 1.5(IQR); IQR = Q3-Q1
#Maximum Outlier = Q3 + 1.5(IQR)

# %%
sns.scatterplot(x = hd['chol'], y = hd['thalach'])
